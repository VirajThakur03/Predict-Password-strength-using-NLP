# %% [markdown]
# <a href="https://colab.research.google.com/github/VirajThakur03/Predict-Password-strength-using-NLP/blob/main/NLP_password_strength_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Collection

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sqlite3

# %%
sq = sqlite3.connect(r"/content/drive/MyDrive/Colab Notebooks/password_data.sqlite")

# %%
data = pd.read_sql_query("SELECT * FROM Users",sq)

# %%
data.head(1)
# Out:
#    index   password  strength
# 0      0  zxe870819         1

# %%
data.shape
# Out:
# (100000, 3)

# %%
data.drop(["index"],axis=1,inplace=True)

# %%
data.head(1)
# Out:
#     password  strength
# 0  zxe870819         1

# %% [markdown]
# Data Cleaning

# %%
data.isnull().sum()
# Out:
# password    0
# strength    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# password    False
# strength    False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dtypes
# Out:
# password    object
# strength     int64
# dtype: object

# %%
data["strength"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        2
# 4        1
#         ..
# 99995    1
# 99996    1
# 99997    1
# 99998    1
# 99999    1
# Name: strength, Length: 100000, dtype: int64

# %%
data["strength"].unique()
# Out:
# array([1, 2, 0])

# %% [markdown]
# Data Analysis

# %%
data["password"].str.isnumeric()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: password, Length: 100000, dtype: bool

# %%
data[data["password"].str.isnumeric()]
# Out:
#       password  strength
# 12280   943801         0
# 14992    12345         0
# 20958   147856         0
# 21671   140290         0
# 23269   123987         0
# 28569  1233214         0
# 31329  0159456         0
# 32574   363761         0
# 37855  4524344         0
# 43648  5521597         0
# 45271   626262         0
# 52266   156651         0
# 58717      369         0
# 59619   151106         0
# 67723     1234         0
# 68106  1995151         0
# 68592   112233         0
# 69255  9562489         0
# 74938       12         0
# 77298    18731         0
# 86406     1050         0
# 86608   158491         0
# 94908   060415         0
# 96459        1         0
# 98122  6975818         0
# 98248   454545         0

# %%
data[data["password"].str.isupper()]
# Out:
#           password  strength
# 115       EYT63119         1
# 273      INSPIRON6         1
# 338       1A2S3D4F         1
# 367      13269123A         1
# 373     YAMAZAKI82         1
# ...            ...       ...
# 99590   V13000993J         1
# 99692  65925013ABC         1
# 99784     01EDD055         1
# 99893     1UPONYOU         1
# 99910       UNION1         0
#
# [1506 rows x 2 columns]

# %%
data[data["password"].str.isalpha()]
# Out:
#          password  strength
# 267    PomarancaÇ         1
# 1380       smgodt         0
# 3198        cuado         0
# 4560        jelsz         0
# 6380       demsxp         0
# 7803       secret         0
# 9218      caballo         0
# 11555         mhe         0
# 11667      kreedo         0
# 13645     nõmlich         0
# 14665     tahiana         0
# 14890      bolaos         0
# 16741      sherry         0
# 18066      llÚÚßß         0
# 19500       maraa         0
# 25572       akido         0
# 26472       abcde         0
# 28238       HAMED         0
# 29116      cacinG         0
# 31029      indißn         0
# 32283      niatkm         0
# 36935     sarokkd         0
# 46289     zxcvbnm         0
# 48091      taison         0
# 48204     jasacom         0
# 48943      elseor         0
# 49608      elango         0
# 51434     lestari         0
# 52874     anhyeem         0
# 56272      briceo         0
# 61580       askim         0
# 61993      dßniel         0
# 63031      kimota         0
# 67165      trcske         0
# 67593      BRTTAM         0
# 69501       cuada         0
# 73125     hepkret         0
# 74049       anann         0
# 74553     kobraak         0
# 75073     glemlak         0
# 75294     jgkocka         0
# 76977     Dungeon         0
# 78199     nikuÜka         0
# 80307      castao         0
# 82638     winseen         0
# 84115       sayap         0
# 85423       adgjl         0
# 89287     nyomork         0
# 92715     regipek         0
# 92992       grkan         0

# %%
data[data["password"].str.isalnum()]
# Out:
#            password  strength
# 0         zxe870819         1
# 1      xw46454nr23l         1
# 2         soporte13         1
# 4          c443balg         1
# 5         16623670p         1
# ...             ...       ...
# 99995    obejofi215         1
# 99996    fmiopvxb64         1
# 99997     czvrbun38         1
# 99998     mymyxe430         1
# 99999   glqjhkxb467         1
#
# [97203 rows x 2 columns]

# %%
data[data["password"].str.istitle()]
# Out:
#                   password  strength
# 64       Hisanthoshjasika0         2
# 242    Therockrockbottom72         2
# 338               1A2S3D4F         1
# 367              13269123A         1
# 526        Csicskarozsika1         2
# ...                    ...       ...
# 99168          1053815198M         1
# 99192      Alfranx05122023         2
# 99375       Kensington1956         2
# 99590           V13000993J         1
# 99654       94010Centuripe         2
#
# [932 rows x 2 columns]

# %%
import string

# %%
special = string.punctuation

# %%
def special_char(row):
  for char in row:
    if char in special:
      return True
  return False

# %%
data["password"].apply(special_char)
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: password, Length: 100000, dtype: bool

# %%
data[data["password"].apply(special_char)]
# Out:
#                       password  strength
# 3      accounts6000webhost.com         2
# 68                12463773800+         1
# 98                  p.r.c.d.g.         1
# 145                  cita-cita         1
# 180         karolina.susnina0U         2
# ...                        ...       ...
# 99748             maiselis.com         1
# 99845          hosting4meze!@#         2
# 99954         semista_bakung15         2
# 99980         halflife2010!LEB         2
# 99988                lbhtrnjh@         1
#
# [2663 rows x 2 columns]

# %% [markdown]
# Applying Feature Egineering

# %%
data["length"]=data["password"].str.len()

# %%
data.columns
# Out:
# Index(['password', 'strength', 'length'], dtype='object')

# %%
password="shan065"

# %%
a = [char for char in password if char.islower()]
print(len(a))
# Out:
# 4

# %%
def frequency_lower(row):
  return len([char for char in row if char.islower()])/len(row)

# %%
def frequency_upper(row):
  return len([char for char in row if char.isupper()])/len(row)

# %%
def frequency_number(row):
  return len([char for char in row if char.isnumeric()])/len(row)

# %%
def frequency_special(row):
  special=[]
  for char in row:
    if not char.isdigit() and not char.isalpha():
      special.append(char)
  return len(special)/len(row)

# %%
data["lower_frequency"]=np.round(data["password"].apply(frequency_lower),3)
data["upper_frequency"]=np.round(data["password"].apply(frequency_upper),3)
data["number_frequency"]=np.round(data["password"].apply(frequency_number),3)
data["special_frequency"]=np.round(data["password"].apply(frequency_special),3)

# %%
data.head(10)
# Out:
#                   password  strength  length  lower_frequency  \
# 0                zxe870819         1       9            0.333
# 1             xw46454nr23l         1      12            0.417
# 2                soporte13         1       9            0.778
# 3  accounts6000webhost.com         2      23            0.783
# 4                 c443balg         1       8            0.625
# 5                16623670p         1       9            0.111
# 6                 yj9q3f8p         1       8            0.625
# 7          180ZIRUVIcuFERy         2      15            0.200
# 8                 djredd09         1       8            0.750
# 9                yin172015         1       9            0.333
#
#    upper_frequency  number_frequency  special_frequency
# 0              0.0             0.667              0.000
# 1              0.0             0.583              0.000
# 2              0.0             0.222              0.000
# 3              0.0             0.174              0.043
# 4              0.0             0.375              0.000
# 5              0.0             0.889              0.000
# 6              0.0             0.375              0.000
# 7              0.6             0.200              0.000
# 8              0.0             0.250              0.000
# 9              0.0             0.667              0.000
